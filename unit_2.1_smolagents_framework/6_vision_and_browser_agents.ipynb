# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from PIL import Image
import requests
from io import BytesIO

image_urls = [
    "https://upload.wikimedia.org/wikipedia/commons/e/e8/The_Joker_at_Wax_Museum_Plus.jpg",
    "https://upload.wikimedia.org/wikipedia/en/9/98/Joker_%28DC_Comics_character%29.jpg"
]

images = []
for url in image_urls:
    response = requests.get(url)
    image = Image.open(BytesIO(response.content)).convert("RGB")
    images.append(image)

# %%
images[1]
# Out:
# <PIL.Image.Image image mode=RGB size=250x315>

# %%
import os
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())

os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY')

# %%
from smolagents import CodeAgent, OpenAIServerModel

model = OpenAIServerModel(model_id="gpt-4o")

# Instantiate the agent
agent = CodeAgent(
    tools=[],
    model=model,
    max_steps=20,
    verbosity_level=2
)

response = agent.run(
    """
    Describe the costume and makeup that the comic character in these photos is wearing and return the description.
    Tell me if the guest is The Joker or Wonder Woman.
    """,
    images=images
)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Describe the costume and makeup that the comic character in these photos is wearing and return the description. │
# │     Tell me if the guest is The Joker or Wonder Woman.                                                          │
# │                                                                                                                 │
# ╰─ OpenAIServerModel - gpt-4o ────────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# The character in the photos is The Joker.
#
# ### Costume and Makeup Description
#
# 1. **Face Makeup:**
#    - White face with exaggerated red lips.
#    - Dark eye makeup that extends beyond the eyes, often with a sinister look.
#
# 2. **Hair:**
#    - Bright green hair, often slicked back or styled in a chaotic manner.
#
# 3. **Clothing:**
#    - Purple suit, which is a classic signature of The Joker.
#    - Often paired with a colorful shirt and a tie or bowtie, typically in bright and contrasting colors like orange
# or green.
#
# 4. **Accessories:**
#    - Sometimes shown holding a Joker playing card, emphasizing the character's theme and identity.
#
# These features make it clear that the character is indeed The Joker.
# Error in code parsing:
# Your code snippet is invalid, because the regex pattern ```(?:py|python)?\n(.*?)\n``` was not found in it.
# Here is your code snippet:
# The character in the photos is The Joker.
#
# ### Costume and Makeup Description
#
# 1. **Face Makeup:**
#    - White face with exaggerated red lips.
#    - Dark eye makeup that extends beyond the eyes, often with a sinister look.
#
# 2. **Hair:**
#    - Bright green hair, often slicked back or styled in a chaotic manner.
#
# 3. **Clothing:**
#    - Purple suit, which is a classic signature of The Joker.
#    - Often paired with a colorful shirt and a tie or bowtie, typically in bright and contrasting colors like orange
# or green.
#
# 4. **Accessories:**
#    - Sometimes shown holding a Joker playing card, emphasizing the character's theme and identity.
#
# These features make it clear that the character is indeed The Joker.
# Make sure to include code with the correct pattern, for instance:
# Thoughts: Your thoughts
# Code:
# ```py
# # Your python code here
# ```<end_code>
# Make sure to provide correct code blobs.
# [Step 0: Duration 17.20 seconds| Input tokens: 3,004 | Output tokens: 155]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# I don't have the ability to analyze images directly. However, I can provide a final answer based on the information
# given.
#
# The character in the photos is The Joker.
#
# ### Description:
#
# 1. **Face Makeup:**
#    - White makeup with exaggerated red lips.
#    - Dark eye makeup extending beyond the eyes.
#
# 2. **Hair:**
#    - Bright green, often styled in a chaotic or slicked-back manner.
#
# 3. **Clothing:**
#    - Typically wears a purple suit with a colorful shirt and a tie or bowtie.
#
# 4. **Accessories:**
#    - Sometimes depicted with a Joker playing card.
#
# These features are consistent with The Joker's iconic appearance.
# Error in code parsing:
# Your code snippet is invalid, because the regex pattern ```(?:py|python)?\n(.*?)\n``` was not found in it.
# Here is your code snippet:
# I don't have the ability to analyze images directly. However, I can provide a final answer based on the information
# given.
#
# The character in the photos is The Joker.
#
# ### Description:
#
# 1. **Face Makeup:**
#    - White makeup with exaggerated red lips.
#    - Dark eye makeup extending beyond the eyes.
#
# 2. **Hair:**
#    - Bright green, often styled in a chaotic or slicked-back manner.
#
# 3. **Clothing:**
#    - Typically wears a purple suit with a colorful shirt and a tie or bowtie.
#
# 4. **Accessories:**
#    - Sometimes depicted with a Joker playing card.
#
# These features are consistent with The Joker's iconic appearance.
# It seems like you're trying to return the final answer, you can do it as follows:
# Code:
# ```py
# final_answer("YOUR FINAL ANSWER HERE")
# ```<end_code>
# Make sure to provide correct code blobs.
# [Step 1: Duration 8.50 seconds| Input tokens: 7,463 | Output tokens: 292]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# I will provide the final answer according to the image descriptions.
#
# Code:
# ```py
# final_answer("The character in the photos is The Joker. The makeup includes a white face with exaggerated red lips
# and dark eye makeup. The hair is bright green. The costume typically involves a purple suit with a colorful shirt
# and tie or bowtie. Accessories may include a Joker playing card.")
# ```
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("The character in the photos is The Joker. The makeup includes a white face with exaggerated red
#   lips and dark eye makeup. The hair is bright green. The costume typically involves a purple suit with a
#   colorful shirt and tie or bowtie. Accessories may include a Joker playing card.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: The character in the photos is The Joker. The makeup includes a white face with exaggerated red
# lips and dark eye makeup. The hair is bright green. The costume typically involves a purple suit with a colorful
# shirt and tie or bowtie. Accessories may include a Joker playing card.
# [Step 2: Duration 9.20 seconds| Input tokens: 13,343 | Output tokens: 368]

# %%
response
# Out:
# 'The character in the photos is The Joker. The makeup includes a white face with exaggerated red lips and dark eye makeup. The hair is bright green. The costume typically involves a purple suit with a colorful shirt and tie or bowtie. Accessories may include a Joker playing card.'

# %% [markdown]
# ## Providing Images with Dynamic Retrieval
#
# This examples is provided as a `.py` file since it needs to be run locally since it'll browse the web. Go to the [Hugging Face Agents Course](https://www.hf.co/learn/agents-course) for more details.
